# %%
import pandas as pd

# %%
import gsheet_pandas

# %%
from pathlib import Path
import gsheet_pandas



secret_path = Path('data_sources').resolve()
gsheet_pandas.setup(credentials_dir=secret_path / 'credentials.json')

# %%
df = pd.from_gsheet(spreadsheet_id='1ghoLFQ6Ydbz0QRMgCfAT2_0fktJSNI4HkHIu6qKWWbU', 
                    sheet_name='szoreg',
                    range_name='!A:L')

# %%
df.head()
# Out:
#   ключ   ID         Район_2 Населеный пункт_2                Адрес_2  \
# 0    1   10  Абанский район           Абан п.      Советская ул., 73
# 1    1   73  Абанский район           Абан п.      Советская ул., 56
# 2    6  124  Абанский район      Березовка с.          Новая ул., 23
# 3   18  125  Абанский район    Долгий Мост с.  Комсомольская ул., 71
# 4   22  126  Абанский район       Заозерка с.     Сибирская ул., 23а
#
#                                         Адрес полный Технология подключения  \
# 0         Абанский район, Абан п., Советская ул., 73                 Оптика
# 1         Абанский район, Абан п., Советская ул., 56                   Медь
# 2        Абанский район, Березовка с., Новая ул., 23                   Медь
# 3  Абанский район, Долгий Мост с., Комсомольская ...                   Медь
# 4    Абанский район, Заозерка с., Сибирская ул., 23а                Спутник
#
#   Функциональный заказчик                             Учреждение  \
# 0            Аг.Занятости            КГКУ "ЦЗН Абанского района"
# 1               Аг.Печати  КГАУ «Редакция газеты «Красное знамя»
# 2               ВетНадзор                 Березовский ветучасток
# 3               ВетНадзор         Долго- Мостовская Ветлечебница
# 4               ВетНадзор       Заозерновский ветеринарный пункт
#
#             Скорость                       Контракт Изменение
# 0       до 50 Мбит/с         194/14 от 10.02.2015г.      None
# 1        до 5 Мбит/с         194/14 от 10.02.2015г.      None
# 2        до 4 Мбит/с        9686/15 от 05.02.2016г.      None
# 3        до 2 Мбит/с        9686/15 от 05.02.2016г.      None
# 4  не менее 1 Мбит/с  Ф.2018.108131 от 29.03.2018г.      None
